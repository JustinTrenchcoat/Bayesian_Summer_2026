# %%
import numpy as np
from google.colab import drive
from matplotlib.lines import Line2D
from copy import deepcopy
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import pandas as pd

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
max_warmup = 1000
warmup_window = 100

window_array = np.append(np.repeat(10, 10),
                      np.repeat(warmup_window, max_warmup // warmup_window - 1))

warmup_length = np.repeat(10, len(window_array))
for i in range(len(warmup_length) - 1):
    warmup_length[i + 1] = warmup_length[i] + window_array[i + 1]

# Transition kernel for short regime
repitition = 10
num_chains_short = 2048
num_super_chains = 16

# %%
# quantiles for chi squared with df = 1
chi_up = 3.841459 # 95th quantile for chi squared with df = 1
chi_lo = 0.00393214  # 05th quantile for chi squared with df = 1
tau = 1e-4
num_chains_short = 2048
num_super_chains = 16
M = num_chains_short // num_super_chains
nRhat_lower = np.sqrt(1 + 1 / M + tau)
eps_lower = nRhat_lower - 1
bound = [chi_lo / num_chains_short, chi_up / num_chains_short]
threshold = eps_lower

# %%
utility_link = '/content/drive/MyDrive/Colab Notebooks/2026_Summer_MCMC/BlackJAXUtil.py'
with open(utility_link) as f: exec(f.read())

# %% [markdown]
# **Rosenbrock**

# %%
MSE_constrained_path = "/content/drive/MyDrive/Colab Notebooks/2026_Summer_MCMC/BlackJAX_pkl_files/Rosen_MSE_constrained.pkl"
MSE_c_df = pd.read_pickle(MSE_constrained_path)
MSE_naive_path = "/content/drive/MyDrive/Colab Notebooks/2026_Summer_MCMC/BlackJAX_pkl_files/Rosen_MSE_naive.pkl"
MSE_n_df = pd.read_pickle(MSE_naive_path)

R_hat_constrained_path = "/content/drive/MyDrive/Colab Notebooks/2026_Summer_MCMC/BlackJAX_pkl_files/Rosen_R_Hat_constrained.pkl"
R_Hat_c_df = pd.read_pickle(R_hat_constrained_path)
R_hat_naive_path = "/content/drive/MyDrive/Colab Notebooks/2026_Summer_MCMC/BlackJAX_pkl_files/Rosen_R_Hat_naive.pkl"
R_Hat_n_df = pd.read_pickle(R_hat_naive_path)

# %%
MSE_vs_Warmup(MSE_c_df, MSE_n_df,"Rosenbrock")

# %%
MSE_vs_Rhat(R_Hat_c_df,
           "Rosenbrock",
           False,
            bound, threshold,num_chains_short,True)

# %%
MSE_vs_Rhat(R_Hat_c_df,
           "Rosenbrock",
           False,
            bound, threshold,num_chains_short,False)

# %%
MSE_vs_Rhat(R_Hat_n_df,
           "Rosenbrock",
           True,
            bound, threshold,num_chains_short,True)

# %%
MSE_vs_Rhat(R_Hat_n_df,
           "Rosenbrock",
           True,
            bound, threshold,num_chains_short,False)

# %% [markdown]
# **Bimodal Plots**

# %%
MSE_constrained_path = "/content/drive/MyDrive/Colab Notebooks/2026_Summer_MCMC/BlackJAX_pkl_files/Bim_MSE_constrained.pkl"
Bimodal_MSE_c_df = pd.read_pickle(MSE_constrained_path)
MSE_naive_path = "/content/drive/MyDrive/Colab Notebooks/2026_Summer_MCMC/BlackJAX_pkl_files/Bim_MSE_naive.pkl"
Bimodal_MSE_n_df = pd.read_pickle(MSE_naive_path)

R_hat_constrained_path = "/content/drive/MyDrive/Colab Notebooks/2026_Summer_MCMC/BlackJAX_pkl_files/Bim_R_Hat_constrained.pkl"
Bimodal_R_Hat_c_df = pd.read_pickle(R_hat_constrained_path)
R_hat_naive_path = "/content/drive/MyDrive/Colab Notebooks/2026_Summer_MCMC/BlackJAX_pkl_files/Bim_R_Hat_naive.pkl"
Bimodal_R_Hat_n_df = pd.read_pickle(R_hat_naive_path)

# %%
MSE_vs_Warmup(Bimodal_MSE_c_df, Bimodal_MSE_n_df,"Bimodal")

# %%
MSE_vs_Rhat(Bimodal_R_Hat_c_df,
           "Bimodal",
           False,
            bound, threshold,num_chains_short,True)

# %%
MSE_vs_Rhat(Bimodal_R_Hat_c_df,
           "Bimodal",
           False,
            bound, threshold,num_chains_short,False)

# %%
MSE_vs_Rhat(Bimodal_R_Hat_n_df,
           "Bimodal",
           True,
            bound, threshold,num_chains_short,True)

# %%
MSE_vs_Rhat(Bimodal_R_Hat_n_df,
           "Bimodal",
           True,
            bound, threshold,num_chains_short,False)

# %% [markdown]
# **Eight School Plots**

# %%
MSE_constrained_path = "/content/drive/MyDrive/Colab Notebooks/2026_Summer_MCMC/BlackJAX_pkl_files/School_MSE_constrained.pkl"
School_MSE_c_df = pd.read_pickle(MSE_constrained_path)
MSE_naive_path = "/content/drive/MyDrive/Colab Notebooks/2026_Summer_MCMC/BlackJAX_pkl_files/School_MSE_naive.pkl"
School_MSE_n_df = pd.read_pickle(MSE_naive_path)

R_hat_constrained_path = "/content/drive/MyDrive/Colab Notebooks/2026_Summer_MCMC/BlackJAX_pkl_files/School_R_Hat_constrained.pkl"
School_R_Hat_c_df = pd.read_pickle(R_hat_constrained_path)
R_hat_naive_path = "/content/drive/MyDrive/Colab Notebooks/2026_Summer_MCMC/BlackJAX_pkl_files/School_R_Hat_naive.pkl"
School_R_Hat_n_df = pd.read_pickle(R_hat_naive_path)

# %%
MSE_vs_Warmup(School_MSE_c_df, School_MSE_n_df,"Eight Schools")

# %%
MSE_vs_Rhat(School_R_Hat_c_df,
           "Eight Schools",
           False,
            bound, threshold,num_chains_short,True)

# %%
MSE_vs_Rhat(School_R_Hat_c_df,
           "Eight Schools",
           False,
            bound, threshold,num_chains_short,False)

# %%
MSE_vs_Rhat(School_R_Hat_n_df,
           "Eight Schools",
           True,
            bound, threshold,num_chains_short,True)

# %%
MSE_vs_Rhat(School_R_Hat_n_df,
           "Eight Schools",
           True,
            bound, threshold,num_chains_short,False)

# %% [markdown]
# **IRT Plots**

# %%
MSE_constrained_path = "/content/drive/MyDrive/Colab Notebooks/2026_Summer_MCMC/BlackJAX_pkl_files/IRT_MSE_constrained.pkl"
MSE_constrained_df = pd.read_pickle(MSE_constrained_path)
MSE_naive_path = "/content/drive/MyDrive/Colab Notebooks/2026_Summer_MCMC/BlackJAX_pkl_files/IRT_MSE_naive.pkl"
MSE_naive_df = pd.read_pickle(MSE_naive_path)

R_hat_constrained_path = "/content/drive/MyDrive/Colab Notebooks/2026_Summer_MCMC/BlackJAX_pkl_files/IRT_R_Hat_constrained.pkl"
R_hat_constrained_df = pd.read_pickle(R_hat_constrained_path)
R_hat_naive_path = "/content/drive/MyDrive/Colab Notebooks/2026_Summer_MCMC/BlackJAX_pkl_files/IRT_R_Hat_naive.pkl"
R_hat_naive_df = pd.read_pickle(R_hat_naive_path)

# %%
MSE_vs_Warmup(MSE_constrained_df,MSE_naive_df,"Item Response Theory")

# %%
MSE_vs_Rhat(R_hat_constrained_df,
           "Item Response Theory",
           False,
            bound, threshold,num_chains_short,True)

# %%
MSE_vs_Rhat(R_hat_constrained_df,
           "Item Response Theory",
           False,
            bound, threshold,num_chains_short,False)

# %%
MSE_vs_Rhat(R_hat_naive_df,
           "Item Response Theory",
           True,
            bound, threshold,num_chains_short,True)

# %%
MSE_vs_Rhat(R_hat_naive_df,
           "Item Response Theory",
           True,
            bound, threshold,num_chains_short,False)
